# %%
import os
import bs4
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
def generate_link(job, location):
    j = job.lower().split()
    l = location.lower()
    return f'https://nl.indeed.com/jobs?q={j[0]}+{j[1]}&l={l}'

# %%
def generate_soup(url, page):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36'}
    URL = f'{url}&start={page}'
    r = requests.get(URL, headers)
    soup = BeautifulSoup(r.content, "html.parser")
    return soup

# %%
def extract_descriptions(link):
    soup = generate_soup(link, 0)
    text = soup.find('div', class_ = 'jobsearch-JobComponent-description icl-u-xs-mt--md')
    return text

# %%
def transform(soup, joblist):
    """
    appends information new vacancies from given webpage (soup) to given joblist
    """
    base = 'https://nl.indeed.com'
    divs = soup.find_all('div', class_ = 'jobsearch-SerpJobCard')
    # loop over vacancies on webpage
    for item in divs:
        title = item.find('a').text.strip()
        company = item.find('span', class_ = 'company').text.strip()
        link = base + item.find('a').get('href')
        try:
            description = extract_descriptions(link)
        except:
            description = None
        # make placeholder for the id
        iden = '_'
        job = {
            'id': iden,
            'title': title,
            'company': company,
            'link': link,
            'description': description
        }
        joblist.append(job)
    return joblist

# %%
def job_to_joblist(job, location, n_pages):
    joblist = []
    # reformated to indeed page format 
    n = (n_pages*10)-10
    link = generate_link(job, location)
    # loop over pages and extract
    for i in range(0, n, 10):
        jobs = generate_soup(link, i)
        transform(jobs, joblist)
    return joblist, job

# %%
def add_id(df, job):
    rangelist = list(range(len(df)))
    # assign prefix based on job
    if job.split()[1][:3] == 'ste':
        prefix = 'DSP'
    elif job.split()[1][:3] == 'sci':
        prefix = 'DS'
    else:
        prefix = 'DOC'
    idlist = [prefix + '_' + str(num) for num in rangelist]
    df['id'] = idlist
    return df

# %%
def joblist_to_dataframe(joblist, job):
    df = pd.DataFrame(joblist)
    path = os.path.abspath(os.getcwd())
    # remove duplicate vacancies
    df = df.drop_duplicates(subset=['title', 'company'], keep='first').reset_index(drop=True)
    # remove rows with nan value
    df.dropna(inplace=True)
    df.reset_index(drop=True, inplace=True)
    # add id to the dataframe
    df = add_id(df, job)
    # store the dataframe locally
    df.to_csv(f'{path}\dataframe_{job}.csv', index=False, header=True)
    return df

# %%
joblist, job = job_to_joblist('data steward', 'amsterdam', 3)

# %%
df = joblist_to_dataframe(joblist, job)

# %%
df
# Out:
#         id                                              title  \
# 0    DSP_0                        Master Data Steward/Analyst
# 1    DSP_1                                 HR Officer (32-36)
# 2    DSP_2  Assistant Professor in Data Management Methodo...
# 3    DSP_3                                      Bi Specialist
# 4    DSP_4                                      Data Engineer
# 5    DSP_5            Product Owner Data Management Mortgages
# 6    DSP_6                   Head of Country Marketing - EMEA
# 7    DSP_7                                    Data Consultant
# 8    DSP_8                              Tech Lead Retail Data
# 9    DSP_9                                      Data Engineer
# 10  DSP_10                                       Data Steward
#
#                        company  \
# 0             Amazing Oriental
# 1      Briddge Legal & Finance
# 2   Universiteit van Amsterdam
# 3                        EVBox
# 4             Amazing Oriental
# 5                          ING
# 6                      Invesco
# 7      Oliver James Associates
# 8                 albert-heijn
# 9                 Carrierecafe
# 10                   Alliander
#
#                                                  link  \
# 0   https://nl.indeed.com/rc/clk?jk=8c43b4b47a79b9...
# 1   https://nl.indeed.com/rc/clk?jk=80aa0ba17a4848...
# 2   https://nl.indeed.com/rc/clk?jk=c2a04b6ad75ab4...
# 3   https://nl.indeed.com/rc/clk?jk=0c572fb57d2630...
# 4   https://nl.indeed.com/rc/clk?jk=e295a29af2e4f6...
# 5   https://nl.indeed.com/rc/clk?jk=deca9994e792aa...
# 6   https://nl.indeed.com/rc/clk?jk=520067950c9eec...
# 7   https://nl.indeed.com/rc/clk?jk=0aa484f4dfdc81...
# 8   https://nl.indeed.com/rc/clk?jk=85c82ad8176310...
# 9   https://nl.indeed.com/rc/clk?jk=f70cb6470c9974...
# 10  https://nl.indeed.com/pagead/clk?mo=r&ad=-6NYl...
#
#                                           description
# 0   [[], [], [[], [<p><b><i>Your Responsibilities:...
# 1   [[], [], [[], [<div><div><p>The Renewal Worksh...
# 2   [[], [], [[<div><div><div>Vacancy details of A...
# 3   [[], [], [We're looking for a BI Specialist to...
# 4   [[], [], [[], [<div><p>As a Data Engineer, you...
# 5   [[], [], [[], [<div><p><b>The Unite Tribe Data...
# 6   [[], [], [[<p>As one of the world’s leading as...
# 7   [[], [], [[<p>For an well respected client of ...
# 8   [[], [], [[<div><h2 class="jobSectionHeader"><...
# 9   [[], [], [[<p>Zonder de Data Engineer geen wer...
# 10  [[], [], [[<p><b>Jouw energie</b></p>, <p>\nAl...
